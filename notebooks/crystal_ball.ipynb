# %% [markdown]
# # Exploratory Crystal Ball and piecewise background
# Run from the repository root or notebooks directory. See `docs/methods.md` for limitations.
# The original exploratory notebook is preserved in `archive/`.

# %%
from pathlib import Path
import sys
repo = Path.cwd() if (Path.cwd() / "analysis").is_dir() else Path.cwd().parent
sys.path.insert(0, str(repo))
from analysis.crystal_ball import main
main([])

# %%
from IPython.display import Image, display
for image in sorted((repo / "results" / "crystal_ball").glob("*.png")):
    display(Image(filename=str(image)))
